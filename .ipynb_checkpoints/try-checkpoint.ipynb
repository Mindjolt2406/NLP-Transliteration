# %%
#If there's a space, treat it like an a, if there is no vowel

# Basic characters

#Vowels 
#When vowels start, it should be treated differently than when it appears after a consonant
#In the starting case, the actual letter matra is used, otherwise its just the shortform of the matra
aa = chr(2366)
half = chr(2381)
ay = chr(2375)
ey = chr(2376)
o = chr(2378)


ka = chr(2325)
kha = chr(2326)
ga = chr(2327)
gha = chr(2328)
Dra = chr(2329)

cha = chr(2330)
Cha = chr(2331)
ja = chr(2332)
jha = chr(2333)
Nya = chr(2334)

Ta = chr(2335)
Tha = chr(2336)
Da = chr(2337)
Dha = chr(2338)
Rra = chr(2339)

ta = chr(2340)
tha = chr(2341)
da = chr(2342)
dha = chr(2343)
na = chr(2344)

nna = chr(2345)

pa = chr(2346)
fa = chr(2347)
ba = chr(2348)
bha = chr(2349)
ma = chr(2350)

ya = chr(2351)
ra = chr(2352)
rna = chr(2353)
la = chr(2354)
lna = chr(2355)
va = chr(2357)

sha = chr(2358)
Sha = chr(2359)
sa = chr(2360)
ha = chr(2361)

# %%
h+ay+l+half+l+o
# Out:
# 'हेल्लॊ'

# %%
for i in range(2304,2400):
    print(chr(i),i)
# Out:
# ऀ 2304
# ँ 2305
# ं 2306
# ः 2307
# ऄ 2308
# अ 2309
# आ 2310
# इ 2311
# ई 2312
# उ 2313
# ऊ 2314
# ऋ 2315
# ऌ 2316
# ऍ 2317
# ऎ 2318
# ए 2319
# ऐ 2320
# ऑ 2321
# ऒ 2322
# ओ 2323
# औ 2324
# क 2325
# ख 2326
# ग 2327
# घ 2328
# ङ 2329
# च 2330
# छ 2331
# ज 2332
# झ 2333
# ञ 2334
# ट 2335
# ठ 2336
# ड 2337
# ढ 2338
# ण 2339
# त 2340
# थ 2341
# द 2342
# ध 2343
# न 2344
# ऩ 2345
# प 2346
# फ 2347
# ब 2348
# भ 2349
# म 2350
# य 2351
# र 2352
# ऱ 2353
# ल 2354
# ळ 2355
# ऴ 2356
# व 2357
# श 2358
# ष 2359
# स 2360
# ह 2361
# ऺ 2362
# ऻ 2363
# ़ 2364
# ऽ 2365
# ा 2366
# ि 2367
# ी 2368
# ु 2369
# ू 2370
# ृ 2371
# ॄ 2372
# ॅ 2373
# ॆ 2374
# े 2375
# ै 2376
# ॉ 2377
# ॊ 2378
# ो 2379
# ौ 2380
# ् 2381
# ॎ 2382
# ॏ 2383
# ॐ 2384
# ॑ 2385
# ॒ 2386
# ॓ 2387
# ॔ 2388
# ॕ 2389
# ॖ 2390
# ॗ 2391
# क़ 2392
# ख़ 2393
# ग़ 2394
# ज़ 2395
# ड़ 2396
# ढ़ 2397
# फ़ 2398
# य़ 2399
